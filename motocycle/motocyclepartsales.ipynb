# %% [markdown]
# ## Motorcycle Parts Sales Analysis: Wholesale Revenue by Product Line, Month, and Warehouse
#
# This analysis focuses on understanding wholesale revenue by product line, month, and warehouse for a motorcycle parts company. The objective is to provide insights into the net revenue generated from wholesale orders, taking into account payment fees, and to identify trends across different months and warehouses.
#
# **Data Source:**
#
# The analysis is based on the `sales` table within the company's database. The table contains the following information:
#
# **Table: `sales`**
#
# | Column        | Data type | Description                                                                  |
# |---------------|-----------|------------------------------------------------------------------------------|
# | order_number  | VARCHAR   | Unique order number.                                                          |
# | date          | DATE      | Date of the order, ranging from June to August 2021.                        |
# | warehouse     | VARCHAR   | The warehouse that the order was made from: North, Central, or West.         |
# | client_type   | VARCHAR   | Whether the order was Retail or Wholesale.                                  |
# | product_line  | VARCHAR   | Type of product ordered.                                                     |
# | quantity      | INT       | Number of products ordered.                                                  |
# | unit_price    | FLOAT     | Price per product (dollars).                                                  |
# | total         | FLOAT     | Total price of the order (dollars).                                             |
# | payment       | VARCHAR   | Payment method: Credit card, Transfer, or Cash.                             |
# | payment_fee   | FLOAT     | Percentage of total charged as a result of the payment method.                 |
#
# **Analysis Requirements:**
#
# The board of directors requires a breakdown of net wholesale revenue by product line, grouped by month and warehouse.  The analysis should:
#
# 1.  **Filter for Wholesale Orders:**  Only include orders where `client_type` is "Wholesale".
# 2.  **Calculate Net Revenue:**  Calculate the net revenue for each order by subtracting the payment fee from the total order value.  The `payment_fee` column represents the percentage of the `total` charged as a fee.
# 3.  **Group by Product Line, Month, and Warehouse:** Group the results by `product_line`, the month extracted from the `date` column, and `warehouse`.
# 4.  **Present Results:**  Provide a clear and concise summary of the net wholesale revenue for each product line, month, and warehouse combination.
# ```

# %%
import pandas as pd

# %%
# net_revenue by product_line
revenue_by_product_line = pd.read_csv('revenue_by_product_line.csv')

# %%
revenue_by_product_line.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_8af58_row0_col3, #T_8af58_row4_col3 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_8af58_row1_col3 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_8af58_row2_col3 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_8af58_row3_col3 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_8af58_row5_col3 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_8af58_row6_col3 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_8af58_row7_col3 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_8af58_row8_col3, #T_8af58_row11_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_8af58_row9_col3 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_8af58_row10_col3, #T_8af58_row26_col3, #T_8af58_row33_col3 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_8af58_row12_col3 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_8af58_row13_col3 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_8af58_row14_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_8af58_row15_col3 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_8af58_row16_col3 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_8af58_row17_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8af58_row18_col3 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_8af58_row19_col3 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_8af58_row20_col3 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_8af58_row21_col3 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_8af58_row22_col3 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_8af58_row23_col3 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_8af58_row24_col3, #T_8af58_row32_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_8af58_row25_col3 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_8af58_row27_col3 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_8af58_row28_col3 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_8af58_row29_col3 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_8af58_row30_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_8af58_row31_col3 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_8af58_row34_col3 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_8af58_row35_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_8af58_row36_col3 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_8af58_row37_col3 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_8af58_row38_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_8af58_row39_col3 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_8af58_row40_col3 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_8af58_row41_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_8af58_row42_col3 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_8af58_row43_col3 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_8af58_row44_col3 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_8af58_row45_col3 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_8af58_row46_col3 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_8af58_row47_col3 {
#   background-color: #d0edca;
#   color: #000000;
# }
# </style>
# <table id="T_8af58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8af58_level0_col0" class="col_heading level0 col0" >product_line</th>
#       <th id="T_8af58_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_8af58_level0_col2" class="col_heading level0 col2" >warehouse</th>
#       <th id="T_8af58_level0_col3" class="col_heading level0 col3" >net_revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8af58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8af58_row0_col0" class="data row0 col0" >Braking system</td>
#       <td id="T_8af58_row0_col1" class="data row0 col1" >August</td>
#       <td id="T_8af58_row0_col2" class="data row0 col2" >Central</td>
#       <td id="T_8af58_row0_col3" class="data row0 col3" >3039.489746</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8af58_row1_col0" class="data row1 col0" >Braking system</td>
#       <td id="T_8af58_row1_col1" class="data row1 col1" >August</td>
#       <td id="T_8af58_row1_col2" class="data row1 col2" >West</td>
#       <td id="T_8af58_row1_col3" class="data row1 col3" >2500.719971</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8af58_row2_col0" class="data row2 col0" >Braking system</td>
#       <td id="T_8af58_row2_col1" class="data row2 col1" >August</td>
#       <td id="T_8af58_row2_col2" class="data row2 col2" >North</td>
#       <td id="T_8af58_row2_col3" class="data row2 col3" >1770.900146</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8af58_row3_col0" class="data row3 col0" >Braking system</td>
#       <td id="T_8af58_row3_col1" class="data row3 col1" >July</td>
#       <td id="T_8af58_row3_col2" class="data row3 col2" >Central</td>
#       <td id="T_8af58_row3_col3" class="data row3 col3" >3778.729980</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8af58_row4_col0" class="data row4 col0" >Braking system</td>
#       <td id="T_8af58_row4_col1" class="data row4 col1" >July</td>
#       <td id="T_8af58_row4_col2" class="data row4 col2" >West</td>
#       <td id="T_8af58_row4_col3" class="data row4 col3" >3060.999756</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8af58_row5_col0" class="data row5 col0" >Braking system</td>
#       <td id="T_8af58_row5_col1" class="data row5 col1" >July</td>
#       <td id="T_8af58_row5_col2" class="data row5 col2" >North</td>
#       <td id="T_8af58_row5_col3" class="data row5 col3" >2594.490234</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8af58_row6_col0" class="data row6 col0" >Braking system</td>
#       <td id="T_8af58_row6_col1" class="data row6 col1" >June</td>
#       <td id="T_8af58_row6_col2" class="data row6 col2" >Central</td>
#       <td id="T_8af58_row6_col3" class="data row6 col3" >3684.989990</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8af58_row7_col0" class="data row7 col0" >Braking system</td>
#       <td id="T_8af58_row7_col1" class="data row7 col1" >June</td>
#       <td id="T_8af58_row7_col2" class="data row7 col2" >North</td>
#       <td id="T_8af58_row7_col3" class="data row7 col3" >1487.809937</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8af58_row8_col0" class="data row8 col0" >Braking system</td>
#       <td id="T_8af58_row8_col1" class="data row8 col1" >June</td>
#       <td id="T_8af58_row8_col2" class="data row8 col2" >West</td>
#       <td id="T_8af58_row8_col3" class="data row8 col3" >1212.770020</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8af58_row9_col0" class="data row9 col0" >Electrical system</td>
#       <td id="T_8af58_row9_col1" class="data row9 col1" >August</td>
#       <td id="T_8af58_row9_col2" class="data row9 col2" >North</td>
#       <td id="T_8af58_row9_col3" class="data row9 col3" >4721.200195</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8af58_row10_col0" class="data row10 col0" >Electrical system</td>
#       <td id="T_8af58_row10_col1" class="data row10 col1" >August</td>
#       <td id="T_8af58_row10_col2" class="data row10 col2" >Central</td>
#       <td id="T_8af58_row10_col3" class="data row10 col3" >3126.479980</td>
#     </tr>
#     <tr>
#       <th id="T_8af58_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8af58_row11_col0" class="data row11 col0" >Electrical sy
